# %%
import os
import sys

from PIL import Image

# %%
#base_dir = os.getcwd() + "/img/"
base_dir = '/home/ss/Yolo_mark/x64/Release/data/img/'
output_dir = '/home/ss/Yolo_mark/x64/Release/data/img/output/'
print(base_dir)
# Out:
# /home/ss/Yolo_mark/x64/Release/data/img/

# %%
os.chdir(base_dir)

# %%
# !pwd
# Out:
# /home/ss/Yolo_mark/x64/Release/data/img

# %%
files = os.listdir('.')
files.sort()
print(files)
# Out:
# ['bycle0.jpg', 'bycle0.txt', 'bycle1.jpg', 'bycle1.txt', 'bycle10.jpg', 'bycle10.txt', 'bycle100.jpg', 'bycle100.txt', 'bycle101.jpg', 'bycle101.txt', 'bycle102.jpg', 'bycle102.txt', 'bycle103.jpg', 'bycle103.txt', 'bycle104.jpg', 'bycle104.txt', 'bycle105.jpg', 'bycle105.txt', 'bycle106.jpg', 'bycle106.txt', 'bycle107.jpg', 'bycle107.txt', 'bycle108.jpg', 'bycle108.txt', 'bycle109.jpg', 'bycle109.txt', 'bycle11.jpg', 'bycle11.txt', 'bycle110.jpg', 'bycle110.txt', 'bycle111.jpg', 'bycle111.txt', 'bycle112.jpg', 'bycle112.txt', 'bycle113.jpg', 'bycle113.txt', 'bycle114.jpg', 'bycle114.txt', 'bycle115.jpg', 'bycle115.txt', 'bycle116.jpg', 'bycle116.txt', 'bycle117.jpg', 'bycle117.txt', 'bycle118.jpg', 'bycle118.txt', 'bycle119.jpg', 'bycle119.txt', 'bycle12.jpg', 'bycle12.txt', 'bycle120.jpg', 'bycle120.txt', 'bycle121.jpg', 'bycle121.txt', 'bycle122.jpg', 'bycle122.txt', 'bycle123.jpg', 'bycle123.txt', 'bycle124.jpg', 'bycle124.txt', 'bycle125.jpg', 'bycle125.txt', 'bycle126.jpg', 'by
# ...

# %%
f_cnt = len(files)
print(f_cnt)
# Out:
# 942

# %%
dir = os.path.exists("./output")
#print(dir)

# %%
#!pwd
#if dir == False:
#    !mkdir output

# %%
import shutil
cnt = 0
cnt2 = 0

for filename in files:
    f_name = filename.split('.')
    if f_name[1] == "txt":
        new_name = 'bycle' + str(cnt) + '.' + f_name[1]
        #print('f_name:'+f_name[0]+'.'+f_name[1])
        print(new_name)
        
        os.rename(base_dir+filename, base_dir+new_name)        
        #shutil.copy(base_dir+filename, output_dir+new_name)
        cnt+=1
    else :
        new_name2 = 'bycle' + str(cnt2) + '.' + f_name[1]
        #print(f_name)
        print(new_name2)
        os.rename(base_dir+filename, base_dir+new_name2)
        #shutil.copy(base_dir+filename, output_dir+new_name2)  
        cnt2+=1
# Out:
# bycle0.jpg
# bycle0.txt
# bycle1.jpg
# bycle1.txt
# bycle2.jpg
# bycle2.txt
# bycle3.jpg
# bycle3.txt
# bycle4.jpg
# bycle4.txt
# bycle5.jpg
# bycle5.txt
# bycle6.jpg
# bycle6.txt
# bycle7.jpg
# bycle7.txt
# bycle8.jpg
# bycle8.txt
# bycle9.jpg
# bycle9.txt
# bycle10.jpg
# bycle10.txt
# bycle11.jpg
# bycle11.txt
# bycle12.jpg
# bycle12.txt
# bycle13.jpg
# bycle13.txt
# bycle14.jpg
# bycle14.txt
# bycle15.jpg
# bycle15.txt
# bycle16.jpg
# bycle16.txt
# bycle17.jpg
# bycle17.txt
# bycle18.jpg
# bycle18.txt
# bycle19.jpg
# bycle19.txt
# bycle20.jpg
# bycle20.txt
# bycle21.jpg
# bycle21.txt
# bycle22.jpg
# bycle22.txt
# bycle23.jpg
# bycle23.txt
# bycle24.jpg
# bycle24.txt
# bycle25.jpg
# bycle25.txt
# bycle26.jpg
# bycle26.txt
# bycle27.jpg
# bycle27.txt
# bycle28.jpg
# bycle28.txt
# bycle29.jpg
# bycle29.txt
# bycle30.jpg
# bycle30.txt
# bycle31.jpg
# bycle31.txt
# bycle32.jpg
# bycle32.txt
# bycle33.jpg
# bycle33.txt
# bycle34.jpg
# bycle34.txt
# bycle35.jpg
# bycle35.txt
# ...
